# %% [markdown]
# <a href="https://colab.research.google.com/github/lauratcc18/IAMINTIC/blob/main/W3Pag10MinticAnalisisUnivariable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Cargar datos
url="https://www.datos.gov.co/resource/w9zh-vetq.csv"
#Conjunto de datos
df=pd.read_csv(url)
#obtener estadisticas descriptivas
print(df.describe())
print(df.columns)
print(df.columns.tolist())
#visualizar histograma y diagrama de caja
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)

sns.histplot(df['montos_desembolsados'],bins=10,kde=True,color='skyblue')
plt.title('HISTOGRAMA montos_desembolsados')

plt.subplot(1,2,2)
sns.boxplot(y='montos_desembolsados',data=df,color='lightcoral')
plt.title('BOXPLOT montos_desembolsados')

plt.show()
# Out:
#        tipo_entidad  codigo_entidad  tasa_efectiva_promedio  \
# count   1000.000000     1000.000000             1000.000000
# mean       1.498000       25.472000               21.417840
# std        2.686487       21.096926               14.831592
# min        1.000000        1.000000                0.000000
# 25%        1.000000        7.000000                1.520000
# 50%        1.000000       26.000000               29.220000
# 75%        1.000000       39.000000               29.440000
# max       32.000000      121.000000               84.740000
#
#        margen_adicional_a_la  montos_desembolsados  numero_de_creditos  \
# count            1000.000000          1.000000e+03         1000.000000
# mean                0.172510          6.683979e+07           14.185000
# std                 1.604767          1.205613e+09          195.151349
# min                -8.000000          2.000000e+00            1.000000
# ...
